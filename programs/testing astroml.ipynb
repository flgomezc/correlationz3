# %%
# %pylab inline
import time
from astroML.correlation import two_point
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DATA = np.loadtxt('../data/SmallCatalog.csv', skiprows=1, delimiter=',',usecols=[0,1])
MASS = np.loadtxt('../data/SmallCatalog.csv', skiprows=1, delimiter=',',usecols=[3,])
RANDOM = np.loadtxt('../data/RandomFieldCatalog01.csv', skiprows=1, delimiter=',',usecols=[0,1])
Conroy = np.genfromtxt("../data/Conroy2006/correlationz3.dat");  ##  Projected correlation function

# %%
np.random.seed(0)
bins = np.logspace(-1, 1, 20)
bins_dist = np.logspace(-1,1,19)

# %%
index = where(MASS>=10**10.0)[0]

t0 = time.time()
corr_10_0 = two_point(DATA,bins, data_R=RANDOM)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_10_0

# %%
index = where(MASS>=10**10.5)[0]

t0 = time.time()
corr_10_5 = two_point(DATA,bins)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_10_5

# %%
index = where(MASS>=10**11.0)[0]

t0 = time.time()
corr_11_0 = two_point(DATA[index],bins, data_R=RANDOM)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_11_0  ### a random field correlation, must be closer to zero.

# %%
n_conroy = 11.0571333672  # Log10 Mass_min to get Conroy Density Number

# %%
index = where(MASS>=10**n_conroy)[0]
print index.shape

t0 = time.time()
corr_conroy = two_point(DATA[index],bins)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0
# Out:
# (234271,)
# 22.978261947631836

# %%
corr_conroy
# Out:
# array([ 0.54307512,  0.41396473,  0.31222565,  0.26691468,  0.24492434,
#         0.2253481 ,  0.18773058,  0.16647566,  0.1469248 ,  0.12365053,
#         0.1058524 ,  0.08983298,  0.07692084,  0.06299051,  0.05325808,
#         0.04383559,  0.03472848,  0.02638622,  0.01929748])

# %%
index = where(MASS>=10**11.5)[0]

t0 = time.time()
corr_11_5 = two_point(DATA[index],bins)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_11_5

# %%
index = where(MASS>=10**12.0)[0]

t0 = time.time()
corr_12_0 = two_point(DATA[index],bins)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_12_0

# %%
index = where(MASS>=10**12.5)[0]

t0 = time.time()
corr_12_5 = two_point(DATA[index],bins)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_12_5

# %%
index = where(MASS>=10**12.5)[0]

t0 = time.time()
corr_12_5 = two_point(DATA,bins)
#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0

# %%
corr_10_0 = array([ 0.15572829,  0.16401834,  0.13705387,  0.11206795,  0.11614301,
        0.09899879,  0.08826248,  0.07696316,  0.06952661,  0.06202156,
        0.05491903,  0.04934412,  0.04296069,  0.03646251,  0.03136299,
        0.02653274,  0.02094332,  0.01599685,  0.01170801])
# N halos = 3898759
# time    = 2128.6 sec

# %%
corr_10_5 = array([ 0.28361101,  0.22654444,  0.19972504,  0.17006316,  0.15151572,
        0.13151613,  0.11514188,  0.10154026,  0.08799077,  0.07749088,
        0.06785   ,  0.05899812,  0.05104333,  0.04280324,  0.03582531,
        0.02965298,  0.02377093,  0.01815358,  0.01321811])
# N halos = 1102192
# time    = 482.7 sec

# %%
corr_11_0 = array([ 0.45930954,  0.39644895,  0.30975834,  0.25589994,  0.25381151,
        0.23395329,  0.19999542,  0.1711214 ,  0.15237369,  0.13168823,
        0.11205819,  0.09915471,  0.08481599,  0.07144365,  0.06017574,
        0.0504164 ,  0.03968121,  0.0306777 ,  0.02261461])
# N_halos = 276193
# time    = 25.4 sec

# %%
corr_11_5 = array([ 0.45930954,  0.39644895,  0.30975834,  0.25589994,  0.25381151,
        0.23395329,  0.19999542,  0.1711214 ,  0.15237369,  0.13168823,
        0.11205819,  0.09915471,  0.08481599,  0.07144365,  0.06017574,
        0.0504164 ,  0.03968121,  0.0306777 ,  0.02261461])
# N_halos = 59865
# time    =  2.3 sec

# %%
corr_12_0 = array([ 0.59090909,  0.92857143,  0.625     ,  0.41052632,  0.53543307,
        0.48584906,  0.75789474,  0.68623482,  0.5244186 ,  0.46888889,
        0.3556338 ,  0.33893957,  0.23756047,  0.18632607,  0.13422199,
        0.12336696,  0.08035396,  0.06097736,  0.05928692])
# H halos = 10375
# time    = 0.15 s

# %%
corr_12_5 = array([        nan,         nan, -1.        ,         nan,  1.        ,
        1.33333333,  1.66666667,  0.77777778,  1.5       ,  1.6       ,
        0.93548387,  1.05      ,  0.77631579,  0.25581395,  0.13364055,
        0.36601307,  0.29243354,  0.06444189,  0.14893617])
# N_halos = 1190
# time    =  0.007s

# %%
B = np.logspace(-1,1,19)

figure(figsize=(8,7))

scatter(Conroy[:,0],Conroy[:,1], label='Conroy et al. 2006' )


plot(B, corr_10_0*250, label=r'$M_{min}=$10^10.0')
plot(B, corr_10_5*250, label=r'$M_{min}=$10^10.5')
plot(B, corr_11_0*250, label=r'$M_{min}=$10^11.0')
plot(B, corr_11_5*250, label=r'$M_{min}=$10^11.5')
plot(B, corr_conroy*250, label=r'$M_{min}=$10^11.057')
plot(B, corr_12_0*250, label=r'$M_{min}=$10^12.0')
plot(B, corr_12_5*250, label=r'$M_{min}=$10^12.5')



xscale('log'); yscale('log')
xlabel(r'Mpc h$^{-1}$', fontsize=25); ylabel(r'$w_p(r)$', fontsize=25)
tick_params(axis='x', labelsize=20)
tick_params(axis='y', labelsize=20)
xlim(0.1,10)
legend(loc=3)
savefig('projected_correlation_astroML00.pdf')

# %%
# Out:
# (234270, 2)

# %%
DATA0    = np.loadtxt('../data/cells/0.csv', skiprows=1, delimiter=',',usecols=[1,2])
DATA1    = np.loadtxt('../data/cells/0.csv', skiprows=1, delimiter=',',usecols=[0,2])
DATA2    = np.loadtxt('../data/cells/0.csv', skiprows=1, delimiter=',',usecols=[1,0])
RANDOM0  = np.loadtxt('../data/cells/R_0.csv', skiprows=1, delimiter=',',usecols=[0,1])
t0 = time.time()
corr0 = two_point(DATA0,bins)
corr1 = two_point(DATA1,bins)
corr2 = two_point(DATA2,bins)


#corr = two_point(DATA, bins, data_R=RANDOM)
tf = time.time()
tf - t0
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-5eacbb539f7e> in <module>()
# ----> 1 DATA0    = np.loadtxt('../data/cells/0.csv', skiprows=1, delimiter=',',usecols=[1,2])
#       2 DATA1    = np.loadtxt('../data/cells/0.csv', skiprows=1, delimiter=',',usecols=[0,2])
#       3 DATA2    = np.loadtxt('../data/cells/0.csv', skiprows=1, delimiter=',',usecols=[1,0])
#       4 RANDOM0  = np.loadtxt('../data/cells/R_0.csv', skiprows=1, delimiter=',',usecols=[0,1])
#       5 t0 = time.time()
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     736                 fh = iter(bz2.BZ2File(fname))
#     737             elif sys.version_info[0] == 2:
# --> 738                 fh = iter(open(fname, 'U'))
#     739             else:
# ...

# %%
B = np.logspace(-1,1,19)

figure(figsize=(8,6))


plot(Conroy[:,0],Conroy[:,1], label='Conroy et al. 2006')

plot(B, corr, label=r'astroML box250')
plot(B, corr0, label='astroML box80')
plot(B, corr1, label='astroML box80')
plot(B, corr2, label='astroML box80')


xscale('log'); yscale('log')
xlabel(r'Mpc h$^{-1}$', fontsize=20); ylabel(r'$w_p(r)$', fontsize=20)
tick_params(axis='x', labelsize=15)
tick_params(axis='y', labelsize=15)
legend(loc=0)
savefig('projected_correlatio_astroML01.pdf')

# %%
B = np.logspace(-1,1,19)

figure(figsize=(8,6))

plot(Conroy[:,0],Conroy[:,1], label='Conroy et al. 2006')

plot(B, corr * 250, label=r'$250\times$ astroML box250')
plot(B, corr0 * 80, label=r'$80\times$ astroML box80')
plot(B, corr1 * 80, label=r'$80\times$ astroML box80')
plot(B, corr2 * 80, label=r'$80\times$ astroML box80')

xscale('log'); yscale('log')
xlabel(r'Mpc h$^{-1}$', fontsize=20); ylabel(r'$w_p(r)$', fontsize=20)
tick_params(axis='x', labelsize=15)
tick_params(axis='y', labelsize=15)
legend(loc=0)
savefig('projected_correlatio_astroML02.pdf')

# %%
B = np.logspace(-1,1,19)

figure(figsize=(8,6))

plot(Conroy[:,0],Conroy[:,1], label='Conroy et al. 2006')

plot(B, corr * 250, label=r'$250\times$ astroML box250')

xscale('log'); yscale('log')
xlabel(r'Mpc h$^{-1}$', fontsize=20); ylabel(r'$w_p(r)$', fontsize=20)
tick_params(axis='x', labelsize=15)
tick_params(axis='y', labelsize=15)
legend(loc=0)
savefig('projected_correlatio_astroML03.pdf')
