# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Conroy = np.genfromtxt("../data/Conroy2006/correlationz3.dat"); 
DIST = np.logspace(-1,2,15)

DD = np.genfromtxt("../results/cells/DD_0.dat", delimiter=',') 
DR = np.genfromtxt("../results/cells/DR_0.dat", delimiter=',') 
RR = np.genfromtxt("../results/cells/RR_0.dat", delimiter=',') 


PCorrFunc = np.zeros(15)
CorrFunc = ( DD -2*DR + RR)/ (RR)     ## Landy-Szalay

for m in range(15):                 ## Integration over R_parallel
    PCorrFunc[m] = sum(CorrFunc[m])
    
PCorrFunc2 = np.zeros(15)
CorrFunc1 = DD/ RR -1               ## Classic
for m in range(15):                 ## Integration over R_parallel
    PCorrFunc2[m] = sum(CorrFunc[m])
# Out:
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: RuntimeWarning: divide by zero encountered in divide
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: RuntimeWarning: invalid value encountered in divide
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: RuntimeWarning: divide by zero encountered in divide
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# Here I plot the correlation function. There is no difference between Landy-Szalay and Peebles estimators.

# %%
fig = figure(figsize=[8,6])
title("Projected Correlation Function at z=3 \n Using P-Bolshoi Database", fontsize=24)

plot(DIST,PCorrFunc, label='Landy-Szalay Estimator')
#for m in range(15):
#    plot(DIST,CorrFunc[m])

scatter(DIST,PCorrFunc2, label='Classic Estimator')

plot(Conroy[:,0],Conroy[:,1], label='Conroy et al. 2006')


yscale('log'); xscale('log')
xlabel(r' $r_p [ \mathrm{Mpc\;h}^{-1}]$', fontsize=20)
ylabel(r'$\omega_p(r_p)$', rotation=90, size=20)

xlim(0.1,10)
#ylim(1,500)
legend()
# Out:
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/matplotlib/scale.py:100: RuntimeWarning: invalid value encountered in less_equal
#   a[a <= 0.0] = 1e-300
